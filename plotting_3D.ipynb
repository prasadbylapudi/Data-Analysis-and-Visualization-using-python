# %%
import numpy as np
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
u=[1,2,3]
v=[3,4]

fig=plt.figure()#create the picture
ax=Axes3D(fig)#darw the 3D plane

ax.plot([0,u[0]],[0,u[1]],[0,u[2]])#all the vectors starts from zero
#plt.axis('equal')
ax.plot([0,0],[0,0],[-5,5],'k--')
ax.plot([0,0],[-5,5],[0,0],'k--')
ax.plot([-5,5],[0,0],[0,0],'k--')
plt.show
# Out:
# <function matplotlib.pyplot.show>
